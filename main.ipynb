# %%
# !pip install -Uqq fastai

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in d:\anaconda3\lib\site-packages (3.4.1)
# Requirement already satisfied: pyyaml in d:\anaconda3\lib\site-packages (from gradio) (6.0)
# Requirement already satisfied: pydub in d:\anaconda3\lib\site-packages (from gradio) (0.23.1)
# Requirement already satisfied: jinja2 in d:\anaconda3\lib\site-packages (from gradio) (2.11.3)
# Requirement already satisfied: requests in d:\anaconda3\lib\site-packages (from gradio) (2.28.1)
# Requirement already satisfied: aiohttp in d:\anaconda3\lib\site-packages (from gradio) (3.8.3)
# Requirement already satisfied: pillow in d:\anaconda3\lib\site-packages (from gradio) (9.2.0)
# Requirement already satisfied: numpy in d:\anaconda3\lib\site-packages (from gradio) (1.21.5)
# Requirement already satisfied: websockets in d:\anaconda3\lib\site-packages (from gradio) (10.3)
# Requirement already satisfied: matplotlib in d:\anaconda3\lib\site-packages (from gradio) (3.5.2)
# Requirement already satisfied: pycryptodome in d:\anaconda3\lib\site-packages (from gradio) (3.15.0)
# Requirement already satisfied: python-multipart in d:\anaconda3\lib\site-packages (from gradio) (0.0.5)
# Requirement already satisfied: fsspec in d:\anaconda3\lib\site-packages (from gradio) (2022.7.1)
# Requirement already satisfied: pandas in d:\anaconda3\lib\site-packages (from gradio) (1.3.5)
# Requirement already satisfied: ffmpy in d:\anaconda3\lib\site-packages (from gradio) (0.3.0)
# Requirement already satisfied: paramiko in d:\anaconda3\lib\site-packages (from gradio) (2.8.1)
# Requirement already satisfied: h11<0.13,>=0.11 in d:\anaconda3\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: httpx in d:\anaconda3\lib\site-packages (from gradio) (0.23.0)
# Requirement already satisfied: fastapi in d:\anaconda3\lib\site-packages (from gradio) (0.85.0)
# Requirement already satisfied: pydantic in d:\anaconda3\lib\site-packages (from gradio) (1.10.2)
# Requirement already satisfied: markdown-it-py[linkify,plugins] in d:\anaconda3\lib\site-packages (from gradio) (2.1.0)
# Requirement already satisfied: orjson in d:\anaconda3\lib\site-packages (from gradio) (3.8.0)
# Requirement already satisfied: uvicorn in d:\anaconda3\lib\site-packages (from gradio) (0.18.3)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\anaconda3\lib\site-packages (from aiohttp->gradio) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\anaconda3\lib\site-packages (from aiohttp->gradio) (21.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\anaconda3\lib\site-packages (from aiohttp->gradio) (1.8.1)
# Requirement already satisfied: asynctest==0.13.0 in d:\anaconda3\lib\site-packages (from aiohttp->gradio) (0.13.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in d:\anaconda3\lib\site-packages (from aiohttp->gradio) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\anaconda3\lib\site-packages (from aiohttp->gradio) (6.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in d:\anaconda3\lib\site-packages (from aiohttp->gradio) (2.0.4)
# Requirement already satisfied: typing-extensions>=3.7.4 in d:\anaconda3\lib\site-packages (from aiohttp->gradio) (4.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\anaconda3\lib\site-packages (from aiohttp->gradio) (1.3.1)
# Requirement already satisfied: starlette==0.20.4 in d:\anaconda3\lib\site-packages (from fastapi->gradio) (0.20.4)
# Requirement already satisfied: anyio<5,>=3.4.0 in d:\anaconda3\lib\site-packages (from starlette==0.20.4->fastapi->gradio) (3.5.0)
# Requirement already satisfied: sniffio in d:\anaconda3\lib\site-packages (from httpx->gradio) (1.2.0)
# Requirement already satisfied: httpcore<0.16.0,>=0.15.0 in d:\anaconda3\lib\site-packages (from httpx->gradio) (0.15.0)
# Requirement already satisfied: certifi in d:\anaconda3\lib\site-packages (from httpx->gradio) (2022.9.24)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in d:\anaconda3\lib\site-packages (from httpx->gradio) (1.5.0)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda3\lib\site-packages (from jinja2->gradio) (2.0.1)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda3\lib\site-packages (from markdown-it-py[linkify,plugins]->gradio) (0.1.2)
# Requirement already satisfied: linkify-it-py~=1.0 in d:\anaconda3\lib\site-packages (from markdown-it-py[linkify,plugins]->gradio) (1.0.3)
# Requirement already satisfied: mdit-py-plugins in d:\anaconda3\lib\site-packages (from markdown-it-py[linkify,plugins]->gradio) (0.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda3\lib\site-packages (from matplotlib->gradio) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda3\lib\site-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda3\lib\site-packages (from matplotlib->gradio) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anaconda3\lib\site-packages (from matplotlib->gradio) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\lib\site-packages (from matplotlib->gradio) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda3\lib\site-packages (from matplotlib->gradio) (1.4.2)
# Requirement already satisfied: pytz>=2017.3 in d:\anaconda3\lib\site-packages (from pandas->gradio) (2022.1)
# Requirement already satisfied: bcrypt>=3.1.3 in d:\anaconda3\lib\site-packages (from paramiko->gradio) (3.2.0)
# Requirement already satisfied: cryptography>=2.5 in d:\anaconda3\lib\site-packages (from paramiko->gradio) (37.0.1)
# Requirement already satisfied: pynacl>=1.0.1 in d:\anaconda3\lib\site-packages (from paramiko->gradio) (1.5.0)
# Requirement already satisfied: six>=1.4.0 in d:\anaconda3\lib\site-packages (from python-multipart->gradio) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests->gradio) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\lib\site-packages (from requests->gradio) (3.3)
# Requirement already satisfied: click>=7.0 in d:\anaconda3\lib\site-packages (from uvicorn->gradio) (8.0.4)
# Requirement already satisfied: cffi>=1.1 in d:\anaconda3\lib\site-packages (from bcrypt>=3.1.3->paramiko->gradio) (1.15.1)
# Requirement already satisfied: importlib-metadata in d:\anaconda3\lib\site-packages (from click>=7.0->uvicorn->gradio) (4.11.3)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from click>=7.0->uvicorn->gradio) (0.4.5)
# Requirement already satisfied: uc-micro-py in d:\anaconda3\lib\site-packages (from linkify-it-py~=1.0->markdown-it-py[linkify,plugins]->gradio) (1.0.1)
# Requirement already satisfied: pycparser in d:\anaconda3\lib\site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko->gradio) (2.21)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda3\lib\site-packages (from importlib-metadata->click>=7.0->uvicorn->gradio) (3.8.0)
# WARNING: Ignoring invalid distribution -cipy (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (d:\anaconda3\lib\site-packages)

# %%
from fastai.vision.all import *
from fastai import *

def is_cat(x): return x[0].isupper()
# Out:
# D:\Anaconda3\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")

# %%
path = untar_data(URLs.PETS)/'images'

# %%
dls = ImageDataLoaders.from_name_func('.',
                                     get_image_files(path), valid_pct=0.2, seed=42,
                                     label_func=is_cat,
                                     item_tfms=Resize(192))
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
dls.show_batch()

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(3)
# Out:
# D:\Anaconda3\lib\site-packages\torchvision\models\_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# D:\Anaconda3\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.201430</td>
#       <td>0.063966</td>
#       <td>0.021651</td>
#       <td>02:05</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.069134</td>
#       <td>0.042896</td>
#       <td>0.013532</td>
#       <td>03:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.036206</td>
#       <td>0.018819</td>
#       <td>0.006766</td>
#       <td>03:55</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.018163</td>
#       <td>0.021780</td>
#       <td>0.008796</td>
#       <td>04:18</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = load_learner('model.pkl')

# %%
labels = learn.dls.vocab
def predict(img):
    img=PILImage.create(img)
    pred, pred_idx, probs = learn.predict(img)
    return {labels[i]: float(probs[i]) for i in range(len(labels))}

# %%
import gradio as gr

# %%
gr.Interface(fn=predict, inputs=gr.inputs.Image(shape=(512, 512)), outputs=gr.outputs.Label(num_top_classes=3)).launch(share=True)
# Out:
# D:\Anaconda3\lib\site-packages\gradio\inputs.py:257: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   "Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components",
# D:\Anaconda3\lib\site-packages\gradio\deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# D:\Anaconda3\lib\site-packages\gradio\outputs.py:197: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   "Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components",
# D:\Anaconda3\lib\site-packages\gradio\deprecation.py:40: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   warnings.warn(value)
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://14606.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://14606.gradio.app" width="900" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x2c1f15a7188>,
#  'http://127.0.0.1:7860/',
#  'https://14606.gradio.app')
